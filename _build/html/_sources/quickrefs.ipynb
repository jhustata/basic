# %% [markdown]
# > *The foundational pillars of this Spring term course were laid by my esteemed mentors and colleagues in the Department of Surgery at Hopkins, [Dorry Segev](https://nyulangone.org/doctors/1326071945/dorry-l-segev) and [Allan Massie](https://med.nyu.edu/faculty/allan-b-massie).*
#
# # Quick References
#
# ## Classroom and Virtual Attendance Information
# - **Location**: Wolfe **W1214** (Sheldon Hall), East Baltimore Campus. You're encouraged to join the in-person experience for enriched learning[.](./quickrefs2.ipynb)
# - **Zoom Online Classroom**: [Join Zoom Meeting](https://jhjhm.zoom.us/j/97089503585). Active participation in Zoom sessions is highly encouraged. Ask questions, share your screen when troubleshooting, and engage with your peers to mimic the in-person classroom environment as closely as possible.
#    - Sessions <strike>and labs</strike> will be recorded and stored in the cloud for 180 days for review and reference. **Passcodes for the recordings can be accessed** via the `CoursePlus > Online Library > Session`
#       + [Week 1](https://jhjhm.zoom.us/rec/share/yN6mcAaK8ZP1afqVUSiyi1QfS_kb75-qQE2xd5keBmcYrcovaMvEnG1NCIEkLuz7.MBZcNaSWdik6RGNP?startTime=1711654849000)
#       + [Week 2](https://jhjhm.zoom.us/rec/share/OLhw70Cptyl4rpBxr143nS6tmVBDfO_e_Jp_EyrtcOa5lT2Ui3Pi0Nt_gdea2FCD.G7co-fT1GNH389WA?startTime=1712259171000)
#       + [Week 3](https://jhjhm.zoom.us/rec/share/VgXtxlUPPSd3hYoSrVeLsI0HPEP55iMZuQDmw_-s8k183m0_JO_pcCb3awkf1yyg.4AVwxaBulr4l2gBd?startTime=1712863901000)
#       + [Week 4](https://jhjhm.zoom.us/rec/share/5Ejfd2Bg6faZ4Gk7fZp7myMLM0_ifLf3uCNybxat3A9Ve70fZqnBq4I72nYhFhzq.t3zYWToMwmu9Gbol?startTime=1713469111000)
#       + [Week 5](https://jhjhm.zoom.us/rec/share/JOEHcN1KOppED4WkMT5aYCf1_ohWm75MomP4477wWz8ANOm1khzIk78IFmaZoJNl.Gd6Zh66xdPFtVAGi?startTime=1714073488000)
#       + Week 6
#       + Week 7
#       + Week 8
#    - Screen sharing during class is recommended for effective troubleshooting.
#
# ## Course Materials and Communications
# - **Syllabus**: [View Syllabus](https://courseplus.jhu.edu/core/index.cfm/go/syl:syl.public.view/catalogID/38901)
# - **CoursePlus Portal**: [Access Course Materials and Forums](https://courseplus.jhu.edu/core/index.cfm/go/course.home/coid/21040/)
#    - Contains video passcodes, discussion forums, and lab Dropbox for assignments.
#
# ## Course Team Contacts
# - **Instructor**:
#    - Abimereki Muzaale[,](teachingteam.md) Email: muzaale@jhmi.edu
# - **Analytic Mentor**:
#    - Vincent Jin, Email: zjin26@jhmi.edu
#
# - **Teaching Assistants**[:](tastudentmatch.md)
#    - Ning Meng, Email: nmeng2@jh.edu (Lead TA)
#    - Natalie Daya Malek, Email: ndaya1@jhu.edu
#    - Xujun Gu, Email: xgu23@jhmi.edu
#    - Maya Aboumrad, Email: maboumr1@jhmi.edu
#    - Darien Colson-Fearon, Email: dcolson3@jhmi.edu
#
# ## Labs Schedule
# **Labs/Office Hours** are scheduled from Monday to Friday. These hours are **an open forum** for you to seek help with homework, lab exercises, or clarify any course material
#    - [Monday, 10-11am](https://JHUBlueJays.zoom.us/j/2972288634)
#    - [Tuesday, 9-10am](https://JHUBlueJays.zoom.us/j/6543760292?pwd=UFVpUnovbyttR3RWNzJzRHpuTlNsdz09)
#    - [Wednesday, 9-10am](https://JHUBlueJays.zoom.us/j/4626758209)
#    - [Thursday, 8:30-9:30am](https://JHUBlueJays.zoom.us/j/6561597759)
#    - [Friday, 12-1pm](https://JHUBlueJays.zoom.us/j/3393703103)
#
# **Lab instructions/solutions**:
# - **Lab 1/Week 2**: [Lab 1 Instructions](https://jhustata.github.io/basic/chapter1.html#lab)  (04/01 - 04/05) | [Solution](lab1sol.md)
# - **Lab 2/Week 3**: [Lab 2 Instructions](lab1.md)  (04/08 - 04/12) | [Solution](lab1sol.md)
# - **Lab 3/Week 4**: [Lab 3 Instructions](lab3.md)  (04/15 - 04/19) | [Solution](lab3sol.md)
# - <strike>**Lab 4/Week 5**: Lab 4 Instructions  (04/22 - 04/26) | Solution</strike>
# - **Lab 5/Week 6**: [Lab 5 Instructions](lab5.md)  (04/29 - 05/02) | Solution
# - **Lab 6/Week 7**: [Lab 6 Instructions](lab6.md)  (05/06 - 05/10) | Solution
# - **Lab 7/Week 8**:[Lab 7 Instructions   (05/13 - 05/17) | Solution
#
# - Ensure to check the specific dates and access the provided solutions for self-review.
#
# ## Homework Assignments
# Assignments are a crucial part of the coursework, allowing you to apply what you've learned:
# - **HW 1**: [Assignment 1](https://jhustata.github.io/basic/chapter1.html#homework) Due 04/04 | [Solution](hw1sol.md)
# - **HW 2**: [Assignment 2](https://jhustata.github.io/basic/chapter2.html#homework) Due 04/11 | [Solution](hw2sol.md)
# - **HW 3**: [Assignment 3](hw3.md) Due 04/18 | [Solution](hw3sol.md)
# - <strike>**HW 4**: Assignment 4 Due 04/25 | Solution </strike> (HW 5 will be your next)
# - **HW 5**: [Assignment 5](hw5.md) Due 05/02 | Solution
# - **HW 6**: [Assignment 6](hw6.md) Due 05/09 | Solution
# - **HW 7**: Assignment 7 Due 05/16 | Solution
#
# - Make sure to submit by the due dates and refer to the solutions for feedback.
#
# ## Datasets and Supplementary Materials
# The course utilizes various datasets and Stata do-files, which are integral for lab exercises and homework:
# - **Datasets**: Available for download or `direct import`, including `transplants.dta`, `donors.dta`, and more, alongside their respective `.txt` versions available for preview.
#    + [transplants.dta](https://github.com/jhustata/basic/raw/main/transplants.dta)
#    + [transplants.txt](https://github.com/jhustata/basic/raw/main/transplants.txt)
#    + [donors.dta](https://github.com/jhustata/basic/raw/main/donors.dta)
#    + [donors.txt](https://github.com/jhustata/basic/raw/main/donors.txt)
#    + [donors_recipients.dta](https://github.com/jhustata/basic/raw/main/donors_recipients.dta)
#    + [donors_recipients.txt](https://github.com/jhustata/basic/raw/main/donors_recipients.txt)
#    + [tx_yr.dta](https://github.com/jhustata/basic/raw/main/tx_yr.dta)
#    + [tx_yr.txt](https://github.com/jhustata/basic/raw/main/tx_yr.txt)
#    + [hw1.tx](https://github.com/jhustata/basic/raw/main/hw1.txt)
#    + [ctr_yr.dta](https://github.com/jhustata/basic/raw/main/ctr_yr.dta)
#    + [hosp.dta](https://github.com/jhustata/basic/raw/main/hosp.dta)
#    + [pra_hist.dta](https://github.com/jhustata/basic/raw/main/pra_hist.dta)
#    + [strpos.dta](https://github.com/jhustata/basic/raw/main/strpos.dta)
#
# - **Supplemental do-files**: Designed to complement lecture materials, available for topics covered in each week.
#    + [lecture1.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture1.do)
#    + [lecture2.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture2.do)
#    + [lecture3.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture3.do)
#    + [lecture4.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture4.do)
#    + [lecture5.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture5.do)
#    + [lecture6.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture6.do)
#    + [lecture7.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture7.do)
#    + [lecture8.do](https://raw.githubusercontent.com/jhustata/basic/main/lecture8.do)
#       - [unique](dofile.md) `.do` file structure
#
# ## Additional Resources and Evaluation
# - **Stata Version Note**: A specific note on Stata 13 usage and compatibility issues is available [here](pvalue.ipynb).
# - **Course Evaluation**: Your honest [feedback](https://courseevalsystem.publichealth.jhu.edu/User) is not just appreciated; it's a cornerstone of how this course evolves. Please don't miss out on the chance to shape future iterations in week 8.
# - **Stata-focused Discussion Community on GitHub**: An opportunity to engage with a [broader Hopkins community](https://github.com/jhufena/discussions/discussions) interested in Stata programming. Requires a GitHub account and a willingness to learn and share.
#
# ## Weekly Insights: Updates, Announcements, and Solutions
#
# ```{seealso}
# - **Updated as of 05/02/2024 at 1:41PM**
# - HW5 Link was not working. It's now fixed!
# - Lab6 & HW6 are now available
# ```
#
# ## Rubric for all Your Homeworks
#
# #### Total Points: 100 (no student will lose more than 20 points; some students may score as many as 105 points)
#
# 1. **Code Structure and Documentation**
#    - **Clarity (up to -1 point)**: Deduct if code is disorganized or hard to follow. (`deduct only once, even if several blocks of code are disorganized; use same approach for other issues`)
#    - **Comments (up to -2 points)**: Deduct for inadequate comments explaining code blocks, methods, or variables.
#    - **Readability (up to -1 point)**: Deduct for poor use of spacing, indentation, or naming conventions.
#
# 2. **Execution and Functionality**
#    - **Correctness (up to -3 points)**: Deduct if the script has errors or does not produce the expected output.
#    - **Efficiency (up to -2 points)**: Deduct if code is inefficient with unnecessary repetitions or calculations.
#       - `Based on this point, even the solution we will later share with you isn't perfect; there's about -1 points for repetition in creating the .xlsx file`
#       - `No body is perfect`
#       - `Yet redeeming qualities could see you earn bonus points!`
#    - **Completeness (up to -1 point)**: Deduct if any part of the script is missing or non-functional.
#
# 3. **Data Handling and Analysis**
#    - **Data Import (up to -1 point)**: Deduct if data is incorrectly imported or cleaned.
#    - **Variable Creation (up to -2 points)**: Deduct if variable creation or transformation is incorrect.
#    - **Descriptive Statistics (up to -2 points)**: Deduct if there are errors in the computation or display of statistics.
#
# 4. **Results and Output Quality**
#    - **Table Outputs (up to -2 points)**: Deduct if outputs in both `.log` and `.xlsx` formats are incorrect or unclear.
#    - **Labeling and Presentation (up to -2 points)**: Deduct if variables and results are improperly labeled or presented.
#    - **Interpretation (up to -1 point)**: Deduct if the results are not briefly explained or interpreted correctly.
#
# #### Additional Considerations:
# - **Innovation (Bonus up to +5 points)**: Award for creative approaches that enhance the analysis or presentation. Perhaps five innovations earn five points. Three earn three, etc.
#
#
# ## Acknowledgements
#
# The foundational pillars of this Spring term course were laid by my esteemed mentors and colleagues in the Department of Surgery at Hopkins, [Dorry Segev](https://nyulangone.org/doctors/1326071945/dorry-l-segev) and [Allan Massie](https://med.nyu.edu/faculty/allan-b-massie). Their move to NYU left big shoes to fill, and it has been an absolute honor to continue their legacy.
#
# Having co-taught the summer institute alongside Allan Massie for three years, I've been uniquely prepared for this role, thanks to his exceptional mentorship. The core content of this class, akin to the enduring tune of a [folk song](https://www.youtube.com/watch?v=1OvMqyUeRH0)[,](https://www.youtube.com/@epimass/videos) was originally composed by Allan. With time, we've reinterpreted this melody, introducing new harmonies and dissonances to accommodate the evolution of technology and challenges, including the introduction of this Jupyter Book hosted on GitHub, powered by Python, and navigated with the assistance of GPT-4. My foray into computer programming has been unexpected yet rewarding.
#
# Vincent, your Analytic Mentor, exemplifies the journey from student to teacher, having advanced from being a student in this course to a lead TA, and now, a valued colleague and collaborator in the Department of Surgery. His progression is a testament to the potential that lies within each of you. This course is just the beginning. Like Vincent, many of you have the potential to transition from learners to leaders in the field. Engage deeply, and let's see where this journey takes you
#
# Our teaching assistants are nothing short of remarkable. Their dedication is evident, whether returning from previous years or joining as exceptional doctoral candidates from the Department of Epidemiology, drawn to this course by their passion for teaching. A special note for our MD/MPH students: one of our TAs has seamlessly bridged their MD/MPH experience at the Bloomberg School into two straight years of teaching, enhancing our team's cohesion and your learning experience. She's heading off to residency after this May!
#
# Finally, the positive evolution of this course has been significantly shaped by [feedback](https://courseevalsystem.publichealth.jhu.edu) from over 300 students across the last two years. This feedback, including detailed critiques from a particularly insightful student, has been instrumental in refining our educational approach, aiming to balance challenge with skill to foster an engaging and productive learning environment.
