# %% [markdown]
# # Quick References
#
# ## Classroom and Virtual Attendance Information
# - **Location**: Wolfe **W1214** (Sheldon Hall), East Baltimore Campus. You're encouraged to join the in-person experience for enriched learning.
# - **Zoom Online Classroom**: [Join Zoom Meeting](https://jhjhm.zoom.us/j/98481767907)
#    - Sessions and labs will be recorded and stored in the cloud for 120 days for review and reference.
#       + Week 1
#       + Week 2
#       + Week 3
#       + Week 4
#       + Week 5
#       + Week 6
#       + Week 7
#       + Week 8
#    - Screen sharing during class is recommended for effective troubleshooting.
#
# ## Course Materials and Communications
# - **Syllabus**: [View Syllabus](https://courseplus.jhu.edu/core/index.cfm/go/syl:syl.public.view/catalogID/38901)
# - **CoursePlus Portal**: [Access Course Materials and Forums](https://courseplus.jhu.edu/core/index.cfm/go/course.home/coid/21040/)
#    - Contains video passcodes, discussion forums, and lab Dropbox for assignments.
#
# ## Course Team Contacts
# - **Instructor**: Abimereki Muzaale, Email: muzaale@jhmi.edu
# - **Analytical Mentors**:
#    - Vincent Jin, Email: zjin26@jhmi.edu
#    - Xujun Gu, Email: xgu23@jhmi.edu
# - **Teaching Assistants**:
#    - Monday: Ning Meng, Email: nmeng2@jh.edu
#    - Tuesday: Darien Colson-Fearon, Email: dcolson3@jhmi.edu
#    - Wednesday: Maya Aboumrad, Email: maboumr1@jhmi.edu
#    - Thursday: Natalie Daya Malek, Email: ndaya1@jhu.edu
#    - Friday: Hejingzi Monica Jia, Email: hjia11@jhu.edu
#
# ## Labs Schedule
# Labs are scheduled from Monday to Friday on specified weeks. Detailed information, including lab materials and solutions, is provided for each lab:
# - **Lab 1/Week 2**: [Lab 1 Instructions](lab1.md) (04/01 - 04/05) | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
# - **Lab 2/Week 3**: [Lab 2 Instructions](lab2.md) (04/08 - 04/12) | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
# - **Lab 3/Week 4**: [Lab 3 Instructions](lab3.md) (04/15 - 04/19) | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
# - **Lab 4/Week 5**: [Lab 4 Instructions](lab4.md) (04/22 - 04/26) | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
# - **Lab 5/Week 6**: [Lab 5 Instructions](lab5.md) (04/29 - 05/02) | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
#
# - Ensure to check the specific dates and access the provided solutions for self-review.
#
# ## Homework Assignments
# Assignments are a crucial part of the coursework, allowing you to apply what you've learned:
# - **HW 1**: [Assignment 1](lab1.md) Due 04/04 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
# - **HW 2**: [Assignment 2](lab2.md) Due 04/11 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
# - **HW 3**: [Assignment 3](lab3.md) Due 04/18 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
# - **HW 4**: [Assignment 4](lab4.md) Due 04/25 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
# - **HW 5**: [Assignment 5](lab5.md) Due 05/02 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
# - **HW 6**: [Assignment 6](lab6.md) Due 05/09 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
# - **HW 7**: [Assignment 7](lab7.md) Due 05/16 | [Solution](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
#
# - Additional homework assignments follow a similar structure. Make sure to submit by the due dates and refer to the solutions for feedback.
#
# ## Datasets and Supplementary Materials
# The course utilizes various datasets and Stata do-files, which are integral for lab exercises and homework:
# - **Datasets**: Available for download or `direct import`, including `transplants.dta`, `donors.dta`, and more, alongside their respective `.txt` versions available for preview.
#    + [transplants.dta](transplants.dta)
#    + [transplants.txt](https://raw.githubusercontent.com/jhustata/livre/main/transplants.txt)
#    + [donors.dta](donors.dta)
#    + [donors.txt](https://raw.githubusercontent.com/jhustata/livre/main/donors.txt)
#    + [donors_recipients.dta](donors_recipients.dta)
#    + [donors_recipients.txt](https://raw.githubusercontent.com/jhustata/livre/main/donors_recipients.txt)
#    + [tx_yr.dta](tx_yr.dta)
#    + [tx_yr.txt](https://raw.githubusercontent.com/jhustata/livre/main/tx_yr.txt)
#
# - **Supplemental do-files**: Designed to complement lecture materials, available for topics covered in each week.
#    + [lecture1.do](lecture1do.md)
#    + [lecture2.do](lecture2do.md)
#    + [lecture3.do](lecture3do.md)
#    + [lecture4.do](lecture4do.md)
#    + [lecture5.do](lecture5do.md)
#    + [lecture6.do](lecture3do.md)
#    + [lecture7.do](lecture4do.md)
#    + [lecture8.do](lecture5do.md)
#
# ## Additional Resources and Evaluation
# - **Stata Version Note**: A specific note on Stata 13 usage and compatibility issues is available [here](pvalue.ipynb).
# - **Course Evaluation**: Your feedback is vital. Please participate in the course evaluation via [Course Evaluation System](https://courseevalsystem.publichealth.jhu.edu/User) in week 8.
# - **Stata-focused Discussion Community on GitHub**: An opportunity to engage with a [broader Hopkins community](https://github.com/jhufena/discussions/discussions) interested in Stata programming. Requires a GitHub account and a willingness to learn and share.
#
# ```{seealso}
# - Updated: 17:53 PM, 03/20/2024
# - Session recordings and passcodes are promptly provided after each class. Check CoursePlus for access.
# - Lab solutions are available following the lab sessions for additional study and practice.
# ```
