# %% [markdown]
# Quick refs
#
# # Quick References
#
# Room
#    + Wolfe **W1214** (Sheldon Hall)
#    + East Baltimore Campus
#    + You're all welcome to join the in-person experience
#
# [Zoom](https://jhjhm.zoom.us/j/98481767907)
#    + Sessions & labs will be recorded
#    + Videos will remain in the cloud for 120 days
#    + Helpful to share your screen when troubleshooting during class
#
# Recordings
#    + Week 1
#    + Week 2
#    + Week 3
#    + Week 4
#    + Week 5
#    + Week 6
#    + Week 7
#    + Week 8
#
# [Syllabus](https://courseplus.jhu.edu/core/index.cfm/go/syl:syl.public.view/catalogID/38901)
#
# [CoursePlus](https://courseplus.jhu.edu/core/index.cfm/go/course.home/coid/21040/)
#    + Content
#       + Video passcodes
#    + Discussion Forum
#    + Lab Dropbox
#
# Your Instructor
#    + Abimereki Muzaale muzaale@jhmi.edu
#
# Analytical Mentors
#    - Vincent Jin zjin26@jhmi.edu
#    - Xujun Gu xgu23@jhmi.edu
#
# Teaching Assistants
#    - M: Ning Meng nmeng2@jh.edu
#    - T: Darien Colson-Fearon dcolson3@jhmi.edu
#    - W: Maya Aboumrad maboumr1@jhmi.edu
#    - Th: Natalie Daya Malek ndaya1@jhu.edu
#    - F: Hejingzi Monica Jia hjia11@jhu.edu
#
# Labs M T W Th F
#    + [Lab 1/Week 2](lab1.md) 04/01 - 04/05 [lab1solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
#    + [Lab 2/Week 3](lab2.md) 04/08 - 04/12 [lab2solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
#    + [Lab 3/Week 4](lab3.md) 04/15 - 04/19 [lab3solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab3solution.do)
#    + [Lab 4/Week 5](lab4.md) 04/22 - 04/26 [lab4solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab4solution.do)
#    + [Lab 5/Week 6](lab5.md) 05/09 - 05/10
#
# Homework
#    + [HW 1](lab1.md) 04/04 [hw1solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
#    + [HW 2](lab2.md) 04/11 [hw2solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
#    + [HW 3](lab3.md) 04/18 [hw3solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab3solution.do)
#    + [HW 4](lab4.md) 04/25 [hw4solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab4solution.do)
#    + [HW 5](lab5.md) 05/02 [hw5solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
#    + [HW 6](lab1.md) 05/09 [hw6solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab1solution.do)
#    + [HW 7](lab2.md) 05/16 [hw7solution.do](https://raw.githubusercontent.com/jhustata/livre/main/lab2solution.do)
#
# Datasets used
#    + [transplants.dta](transplants.dta)
#    + [transplants.txt](https://raw.githubusercontent.com/jhustata/livre/main/transplants.txt)
#    + [donors.dta](donors.dta)
#    + [donors.txt](https://raw.githubusercontent.com/jhustata/livre/main/donors.txt)
#    + [donors_recipients.dta](donors_recipients.dta)
#    + [donors_recipients.txt](https://raw.githubusercontent.com/jhustata/livre/main/donors_recipients.txt)
#    + [tx_yr.dta](tx_yr.dta)
#    + [tx_yr.txt](https://raw.githubusercontent.com/jhustata/livre/main/tx_yr.txt)
#
# Supplemental do-files
#    + [lecture1.do](lecture1do.md)
#    + [lecture2.do](lecture2do.md)
#    + [lecture3.do](lecture3do.md)
#    + [lecture4.do](lecture4do.md)
#    + [lecture5.do](lecture5do.md)
#    + [lecture6.do](lecture3do.md)
#    + [lecture7.do](lecture4do.md)
#    + [lecture8.do](lecture5do.md)
#
# A [note](pvalue.ipynb) on Stata 13
#
# Course [evaluation](https://courseevalsystem.publichealth.jhu.edu/User)
#
# ```{seealso}
# Last updated: 17:53PM 03/20/2024
#
# 1. Video recording of Session 1 has gone live within 2 hours of the lecture
# 2. The passcode for the video recordingwill be available at [CoursePlus > Content > Session 1](https://courseplus.jhu.edu/core/index.cfm/go/home/)
# 3. Solution to lab 1 is available
# ```
